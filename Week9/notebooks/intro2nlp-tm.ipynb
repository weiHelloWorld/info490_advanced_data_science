# %% [markdown]
# <DIV ALIGN=CENTER>
#
# # Introduction to NLP: Topic Modeling
# ## Professor Robert J. Brunner
#
# </DIV>
# -----
# -----

# %% [markdown]
# ## Introduction
#
# When analyzing large text corpora, trends can appear. These trends can
# be repeated use of common phrases or terms that are indicative of common
# underlying themes or topics. For example, books on programming might
# refer to themes such as human computer interaction, optimization and
# performance, or identifying and removing error conditions. Finding these
# common topics can be important for a number of reasons. On the one hand,
# when they are completely unknown, they can be used to provide new
# insight into text documents. On the other hand, when they may be
# partially or even completely unknown, computationally identified topics
# can provide deeper or more concise insight into the relationship between
# documents.
#
# The process of identifying these common topics is known as topic
# modeling, which is generally a form of unsupervised learning. As a
# specific example, consider the [twenty newsgroup][tw] data that we have
# analyzed in scikit learn. While there are twenty different newsgroups,
# it turns out they can be grouped into six related categories: computers,
# sports, science, politics, religion, and miscellaneous. While we now
# these topics ahead of time (from the newsgroup titles), we can apply
# topic modeling to these data to identify the common words or phrases
# that define these common topics.
#
# In the rest of this notebook, we explore the concept of topic modeling.
# First we will use the scikit learn library to perform topic modeling. We
# will introduce and use non-negative matrix factorization and Latent
# Dirchlet allocation. We apply topic modeling to a text classification
# problem, and also explore the terms that make up identified topics.
# Finally, we introduce the gensim library, which provides additional
# techniques for topic modeling.
#
#
# -----
#
# [tw]: http://qwone.com/~jason/20Newsgroups/

# %%
# Set up Notebook

% matplotlib inline

# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# We do this to ignore several specific Pandas warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Load Dataset
from sklearn.datasets import fetch_20newsgroups

train = fetch_20newsgroups(data_home='/home/data_scientist/data/textdm', 
                           subset='train', shuffle=True, random_state=23,
                           remove=('headers', 'footers', 'quotes'))

test = fetch_20newsgroups(data_home='/home/data_scientist/data/textdm', 
                          subset='test', shuffle=True, random_state=23,
                          remove=('headers', 'footers', 'quotes'))

# %%
# Use TD-IDF on newgroup data.
from sklearn.feature_extraction.text import TfidfVectorizer

cv = TfidfVectorizer(stop_words = 'english',
                     lowercase=True,
                     min_df=2,
                     max_features=5000)
                     
train_data = cv.fit_transform(train['data'])
test_data = cv.transform(test['data'])

# %% [markdown]
# -----
#
# ### Non-Negative Matrix Factorization
#
# We can apply [non-negative matrix factorization][wnmf] (NMF) to compute
# topics in a corpus. We start with a term-document matrix, which we
# factor in to a term-feature and a feature-document matrices. The latter
# matrix can be used to identify data clusters (or topics) in the corpus.
# We demonstrate the use of NMF to perform topic modeling by using the
# scikit learn library's [NMF implementation][sknmf].
#
# -----
#
# [wnmf]: https://en.wikipedia.org/wiki/Non-negative_matrix_factorization
# [sknmf]: http://scikit-learn.org/stable/modules/generated/sklearn.decomposition.NMF.html

# %%
# Compute topics by using NMF
from sklearn.decomposition import NMF

num_topics = 30
nmf = NMF(n_components = num_topics, max_iter = 1000).fit(train_data)

# %%
from helper_code import tpterms as tp

nmf_topics = tp.get_topics(cv, nmf)
# Out:
# Topic  0: don think know want say need really try oh mean
# Topic  1: drive drives disk hard floppy cd boot ide internal rom
# Topic  2: geb dsl cadre n3jxp chastity pitt shameful intellect skepticism surrender
# Topic  3: god jesus bible believe faith christ christian christians church life
# Topic  4: windows dos ms version running microsoft os drivers nt driver
# Topic  5: people government gun right law guns state rights make laws
# Topic  6: game team games year players season hockey play win league
# Topic  7: car cars bike engine dealer miles speed driving tires buy
# Topic  8: does know anybody let mean doesn help info appreciated program
# Topic  9: space nasa shuttle launch orbit earth moon station lunar gov
# Topic 10: key chip clipper encryption keys escrow government algorithm nsa security
# Topic 11: scsi ide controller bus isa bit pc devices dma transfer
# Topic 12: like sounds looks look lot things make sound believe new
# Topic 13: just wondering group wanted oh thought work mean ll little
# Topic 14: good luck bad book looking better thing pretty want year
# Topic 15: use used using work way help encryption fonts __ program
# Topic 16: mail address list send post email interested mailing information phone
# Topic 17: edu com cs article university email internet david reply ftp
# Topic 18: window manager application motif server display program widget code xterm
# Topic 19: deleted stuff article day lots guess posted posting eat speed
# Topic 20: mac software need modem pc apple port memory board computer
# Topic 21: 00 sale new shipping offer 10 price condition 50 asking
# Topic 22: card video monitor drivers vga cards driver color bus ati
# Topic 23: armenian armenians turkish genocide turkey armenia turks soviet russian greek
# Topic 24: thanks advance hi info looking help appreciated anybody information appreciate
# Topic 25: problem problems using fix screen fine work error monitor mouse
# Topic 26: ve got seen heard tried recently months believe try hope
# Topic 27: time did didn said years long ago really going ll
# Topic 28: israel israeli jews arab jewish arabs peace lebanon lebanese israelis
# Topic 29: file files ftp program directory format zip image gif bmp

# %% [markdown]
# -----
#
# ### Understanding Topic Terms
#
# We can explore the terms that are important for each topic by creating a
# DataFrame to map our topic terms to the original twenty newsgroups. We
# demonstrate this below by first normalizing the transformed data to have
# unit probability. We use these data to create the DataFrame and group
# the resulting rows by the associated newsgroup as shown below.
#
# -----

# %%
# We transform and normalize the data, 
# by using l1 so document topic probabilty sums to unity.

from sklearn.preprocessing import normalize

td = nmf.transform(train_data)
td_norm = normalize(td, norm='l1', axis=1)

# %%
# We use a DataFrame to simplify the collecting of the data for display.

df = pd.DataFrame(td_norm, columns=nmf_topics)
df.fillna(value=0, inplace=True)
df['label'] = pd.Series(train['target_names'], dtype="category")

df.groupby('label').mean()
# Out:
#                           don, think, know, want, say  \
# label
# alt.atheism                                  0.052816
# comp.graphics                                0.016987
# comp.os.ms-windows.misc                      0.116117
# comp.sys.ibm.pc.hardware                     0.112786
# comp.sys.mac.hardware                        0.000000
# comp.windows.x                               0.051380
# misc.forsale                                 0.000000
# rec.autos                                    0.037552
# rec.motorcycles                              0.044410
# rec.sport.baseball                           0.000000
# rec.sport.hockey                             0.168657
# sci.crypt                                    0.002155
# sci.electronics                              0.000000
# sci.med                                      0.034180
# sci.space                                    0.076416
# soc.religion.christian                       0.216566
# talk.politics.guns                           0.086566
# talk.politics.mideast                        0.071792
# talk.politics.misc                           0.000000
# talk.religion.misc                           0.000000
#
#                           drive, drives, disk, hard, floppy  \
# label
# alt.atheism                                        0.000000
# comp.graphics                                      0.000000
# comp.os.ms-windows.misc                            0.000000
# comp.sys.ibm.pc.hardware                           0.000000
# comp.sys.mac.hardware                              0.000000
# comp.windows.x                                     0.000000
# misc.forsale                                       0.115080
# rec.autos                                          0.000000
# rec.motorcycles                                    0.004839
# rec.sport.baseball                                 0.000000
# rec.sport.hockey                                   0.000000
# sci.crypt                                          0.000000
# sci.electronics                                    0.000000
# sci.med                                            0.014982
# sci.space                                          0.000000
# soc.religion.christian                             0.000589
# talk.politics.guns                                 0.000000
# talk.politics.mideast                              0.314841
# talk.politics.misc                                 0.000000
# talk.religion.misc                                 0.000000
#
#                           geb, dsl, cadre, n3jxp, chastity  \
# label
# alt.atheism                                       0.000000
# comp.graphics                                     0.055501
# comp.os.ms-windows.misc                           0.000000
# comp.sys.ibm.pc.hardware                          0.004353
# comp.sys.mac.hardware                             0.000000
# comp.windows.x                                    0.000000
# misc.forsale                                      0.000000
# rec.autos                                         0.000000
# rec.motorcycles                                   0.007682
# rec.sport.baseball                                0.000000
# rec.sport.hockey                                  0.002548
# sci.crypt                                         0.005489
# sci.electronics                                   0.000000
# sci.med                                           0.013827
# sci.space                                         0.021234
# soc.religion.christian                            0.014759
# talk.politics.guns                                0.000000
# talk.politics.mideast                             0.000000
# talk.politics.misc                                0.000000
# talk.religion.misc                                0.000000
#
#                           god, jesus, bible, believe, faith  \
# label
# alt.atheism                                        0.201349
# comp.graphics                                      0.035428
# comp.os.ms-windows.misc                            0.000000
# comp.sys.ibm.pc.hardware                           0.346079
# comp.sys.mac.hardware                              0.000000
# comp.windows.x                                     0.005713
# misc.forsale                                       0.000000
# rec.autos                                          0.000000
# rec.motorcycles                                    0.020728
# rec.sport.baseball                                 0.000000
# rec.sport.hockey                                   0.062480
# sci.crypt                                          0.000639
# sci.electronics                                    0.000000
# sci.med                                            0.043426
# sci.space                                          0.059700
# soc.religion.christian                             0.000000
# talk.politics.guns                                 0.033263
# talk.politics.mideast                              0.000000
# talk.politics.misc                                 0.000000
# talk.religion.misc                                 0.000000
#
#                           windows, dos, ms, version, running  \
# label
# alt.atheism                                         0.000000
# comp.graphics                                       0.000000
# comp.os.ms-windows.misc                             0.000000
# comp.sys.ibm.pc.hardware                            0.000000
# comp.sys.mac.hardware                               0.208990
# comp.windows.x                                      0.000000
# misc.forsale                                        0.029544
# rec.autos                                           0.000000
# rec.motorcycles                                     0.000000
# rec.sport.baseball                                  0.252040
# rec.sport.hockey                                    0.000000
# sci.crypt                                           0.003193
# sci.electronics                                     0.000000
# sci.med                                             0.001489
# sci.space                                           0.010593
# soc.religion.christian                              0.021026
# talk.politics.guns                                  0.003687
# talk.politics.mideast                               0.016250
# talk.politics.misc                                  0.000000
# talk.religion.misc                                  0.000000
#
#                           people, government, gun, right, law  \
# label
# alt.atheism                                          0.191119
# comp.graphics                                        0.000000
# comp.os.ms-windows.misc                              0.000000
# comp.sys.ibm.pc.hardware                             0.015878
# comp.sys.mac.hardware                                0.000000
# comp.windows.x                                       0.091060
# misc.forsale                                         0.000000
# rec.autos                                            0.000000
# rec.motorcycles                                      0.043357
# rec.sport.baseball                                   0.000000
# rec.sport.hockey                                     0.098435
# sci.crypt                                            0.287391
# sci.electronics                                      0.032846
# sci.med                                              0.041488
# sci.space                                            0.015156
# soc.religion.christian                               0.000000
# talk.politics.guns                                   0.363217
# talk.politics.mideast                                0.000000
# talk.politics.misc                                   0.000000
# talk.religion.misc                                   0.000000
#
#                           game, team, games, year, players  \
# label
# alt.atheism                                       0.029607
# comp.graphics                                     0.000000
# comp.os.ms-windows.misc                           0.071667
# comp.sys.ibm.pc.hardware                          0.000000
# comp.sys.mac.hardware                             0.000000
# comp.windows.x                                    0.000000
# misc.forsale                                      0.000000
# rec.autos                                         0.010273
# rec.motorcycles                                   0.019940
# rec.sport.baseball                                0.000000
# rec.sport.hockey                                  0.001331
# sci.crypt                                         0.000000
# sci.electronics                                   0.000000
# sci.med                                           0.000000
# sci.space                                         0.021783
# soc.religion.christian                            0.000000
# talk.politics.guns                                0.017541
# talk.politics.mideast                             0.000000
# talk.politics.misc                                0.000000
# talk.religion.misc                                0.000000
#
#                           car, cars, bike, engine, dealer  \
# label
# alt.atheism                                      0.011646
# comp.graphics                                    0.000000
# comp.os.ms-windows.misc                          0.000000
# comp.sys.ibm.pc.hardware                         0.003254
# comp.sys.mac.hardware                            0.000000
# comp.windows.x                                   0.275199
# misc.forsale                                     0.000000
# rec.autos                                        0.000000
# rec.motorcycles                                  0.006065
# rec.sport.baseball                               0.000000
# rec.sport.hockey                                 0.035368
# sci.crypt                                        0.000000
# sci.electronics                                  0.002714
# sci.med                                          0.000000
# sci.space                                        0.050728
# soc.religion.christian                           0.016725
# talk.politics.guns                               0.000000
# talk.politics.mideast                            0.000000
# talk.politics.misc                               0.379748
# talk.religion.misc                               0.000000
#
#                           does, know, anybody, let, mean  \
# label
# alt.atheism                                     0.063250
# comp.graphics                                   0.000000
# comp.os.ms-windows.misc                         0.330104
# comp.sys.ibm.pc.hardware                        0.000000
# comp.sys.mac.hardware                           0.265956
# comp.windows.x                                  0.000000
# misc.forsale                                    0.068020
# rec.autos                                       0.000000
# rec.motorcycles                                 0.000000
# rec.sport.baseball                              0.004082
# rec.sport.hockey                                0.019371
# sci.crypt                                       0.000000
# sci.electronics                                 0.000000
# sci.med                                         0.368600
# sci.space                                       0.041228
# soc.religion.christian                          0.134049
# talk.politics.guns                              0.005484
# talk.politics.mideast                           0.143148
# talk.politics.misc                              0.000000
# talk.religion.misc                              0.000000
#
#                           space, nasa, shuttle, launch, orbit  \
# label
# alt.atheism                                          0.010074
# comp.graphics                                        0.000000
# comp.os.ms-windows.misc                              0.000000
# comp.sys.ibm.pc.hardware                             0.019397
# comp.sys.mac.hardware                                0.000000
# comp.windows.x                                       0.000000
# misc.forsale                                         0.000000
# rec.autos                                            0.000000
# rec.motorcycles                                      0.000000
# rec.sport.baseball                                   0.021438
# rec.sport.hockey                                     0.000000
# sci.crypt                                            0.000000
# sci.electronics                                      0.000000
# sci.med                                              0.033881
# sci.space                                            0.000000
# soc.religion.christian                               0.013743
# talk.politics.guns                                   0.000886
# talk.politics.mideast                                0.000000
# talk.politics.misc                                   0.000000
# talk.religion.misc                                   0.000000
#
#                                           ...                   \
# label                                     ...
# alt.atheism                               ...
# comp.graphics                             ...
# comp.os.ms-windows.misc                   ...
# comp.sys.ibm.pc.hardware                  ...
# comp.sys.mac.hardware                     ...
# comp.windows.x                            ...
# misc.forsale                              ...
# rec.autos                                 ...
# rec.motorcycles                           ...
# rec.sport.baseball                        ...
# rec.sport.hockey                          ...
# sci.crypt                                 ...
# sci.electronics                           ...
# sci.med                                   ...
# sci.space                                 ...
# soc.religion.christian                    ...
# talk.politics.guns                        ...
# talk.politics.mideast                     ...
# talk.politics.misc                        ...
# talk.religion.misc                        ...
#
#                           mac, software, need, modem, pc  \
# label
# alt.atheism                                     0.006096
# comp.graphics                                   0.000000
# comp.os.ms-windows.misc                         0.000000
# comp.sys.ibm.pc.hardware                        0.007264
# comp.sys.mac.hardware                           0.270640
# comp.windows.x                                  0.000000
# misc.forsale                                    0.000000
# rec.autos                                       0.000000
# rec.motorcycles                                 0.017394
# rec.sport.baseball                              0.306691
# rec.sport.hockey                                0.012125
# sci.crypt                                       0.000000
# sci.electronics                                 0.000000
# sci.med                                         0.073993
# sci.space                                       0.015434
# soc.religion.christian                          0.054745
# talk.politics.guns                              0.005997
# talk.politics.mideast                           0.000000
# talk.politics.misc                              0.000000
# talk.religion.misc                              0.000000
#
#                           00, sale, new, shipping, offer  \
# label
# alt.atheism                                     0.000000
# comp.graphics                                   0.000000
# comp.os.ms-windows.misc                         0.000000
# comp.sys.ibm.pc.hardware                        0.000000
# comp.sys.mac.hardware                           0.000000
# comp.windows.x                                  0.000000
# misc.forsale                                    0.000000
# rec.autos                                       0.000000
# rec.motorcycles                                 0.000000
# rec.sport.baseball                              0.000000
# rec.sport.hockey                                0.015816
# sci.crypt                                       0.000000
# sci.electronics                                 0.000000
# sci.med                                         0.010858
# sci.space                                       0.002565
# soc.religion.christian                          0.000000
# talk.politics.guns                              0.000000
# talk.politics.mideast                           0.014184
# talk.politics.misc                              0.000000
# talk.religion.misc                              0.000000
#
#                           card, video, monitor, drivers, vga  \
# label
# alt.atheism                                         0.002065
# comp.graphics                                       0.000000
# comp.os.ms-windows.misc                             0.000000
# comp.sys.ibm.pc.hardware                            0.009120
# comp.sys.mac.hardware                               0.000000
# comp.windows.x                                      0.037842
# misc.forsale                                        0.000000
# rec.autos                                           0.000000
# rec.motorcycles                                     0.003216
# rec.sport.baseball                                  0.000000
# rec.sport.hockey                                    0.000000
# sci.crypt                                           0.000000
# sci.electronics                                     0.000000
# sci.med                                             0.000000
# sci.space                                           0.000000
# soc.religion.christian                              0.000000
# talk.politics.guns                                  0.000263
# talk.politics.mideast                               0.098573
# talk.politics.misc                                  0.000000
# talk.religion.misc                                  0.000000
#
#                           armenian, armenians, turkish, genocide, turkey  \
# label
# alt.atheism                                                     0.000000
# comp.graphics                                                   0.000000
# comp.os.ms-windows.misc                                         0.051385
# comp.sys.ibm.pc.hardware                                        0.000000
# comp.sys.mac.hardware                                           0.000000
# comp.windows.x                                                  0.000000
# misc.forsale                                                    0.000000
# rec.autos                                                       0.000000
# rec.motorcycles                                                 0.423984
# rec.sport.baseball                                              0.000000
# rec.sport.hockey                                                0.000000
# sci.crypt                                                       0.019079
# sci.electronics                                                 0.785361
# sci.med                                                         0.000000
# sci.space                                                       0.000674
# soc.religion.christian                                          0.000000
# talk.politics.guns                                              0.083131
# talk.politics.mideast                                           0.000000
# talk.politics.misc                                              0.000000
# talk.religion.misc                                              0.000000
#
#                           thanks, advance, hi, info, looking  \
# label
# alt.atheism                                         0.000000
# comp.graphics                                       0.000000
# comp.os.ms-windows.misc                             0.009839
# comp.sys.ibm.pc.hardware                            0.000000
# comp.sys.mac.hardware                               0.015631
# comp.windows.x                                      0.184654
# misc.forsale                                        0.142954
# rec.autos                                           0.000000
# rec.motorcycles                                     0.000000
# rec.sport.baseball                                  0.030520
# rec.sport.hockey                                    0.000000
# sci.crypt                                           0.000000
# sci.electronics                                     0.000194
# sci.med                                             0.056801
# sci.space                                           0.000000
# soc.religion.christian                              0.003108
# talk.politics.guns                                  0.000000
# talk.politics.mideast                               0.000000
# talk.politics.misc                                  0.124515
# talk.religion.misc                                  0.000000
#
#                           problem, problems, using, fix, screen  \
# label
# alt.atheism                                            0.000000
# comp.graphics                                          0.000000
# comp.os.ms-windows.misc                                0.000000
# comp.sys.ibm.pc.hardware                               0.000000
# comp.sys.mac.hardware                                  0.000000
# comp.windows.x                                         0.008169
# misc.forsale                                           0.107979
# rec.autos                                              0.000000
# rec.motorcycles                                        0.044478
# rec.sport.baseball                                     0.000000
# rec.sport.hockey                                       0.005068
# sci.crypt                                              0.000000
# sci.electronics                                        0.000000
# sci.med                                                0.013012
# sci.space                                              0.004373
# soc.religion.christian                                 0.040143
# talk.politics.guns                                     0.006397
# talk.politics.mideast                                  0.000000
# talk.politics.misc                                     0.000000
# talk.religion.misc                                     0.000000
#
#                           ve, got, seen, heard, tried  \
# label
# alt.atheism                                  0.132149
# comp.graphics                                0.000000
# comp.os.ms-windows.misc                      0.012984
# comp.sys.ibm.pc.hardware                     0.009448
# comp.sys.mac.hardware                        0.000000
# comp.windows.x                               0.158287
# misc.forsale                                 0.000000
# rec.autos                                    0.015152
# rec.motorcycles                              0.061881
# rec.sport.baseball                           0.000000
# rec.sport.hockey                             0.000000
# sci.crypt                                    0.011629
# sci.electronics                              0.114572
# sci.med                                      0.016131
# sci.space                                    0.000000
# soc.religion.christian                       0.013606
# talk.politics.guns                           0.001401
# talk.politics.mideast                        0.000000
# talk.politics.misc                           0.000000
# talk.religion.misc                           0.000000
#
#                           time, did, didn, said, years  \
# label
# alt.atheism                                   0.052252
# comp.graphics                                 0.000000
# comp.os.ms-windows.misc                       0.216705
# comp.sys.ibm.pc.hardware                      0.220553
# comp.sys.mac.hardware                         0.000000
# comp.windows.x                                0.000000
# misc.forsale                                  0.146575
# rec.autos                                     0.000000
# rec.motorcycles                               0.030790
# rec.sport.baseball                            0.003684
# rec.sport.hockey                              0.083779
# sci.crypt                                     0.015125
# sci.electronics                               0.000000
# sci.med                                       0.122727
# sci.space                                     0.104025
# soc.religion.christian                        0.250154
# talk.politics.guns                            0.059513
# talk.politics.mideast                         0.107564
# talk.politics.misc                            0.000000
# talk.religion.misc                            0.000000
#
#                           israel, israeli, jews, arab, jewish  \
# label
# alt.atheism                                          0.007221
# comp.graphics                                        0.000000
# comp.os.ms-windows.misc                              0.000000
# comp.sys.ibm.pc.hardware                             0.035576
# comp.sys.mac.hardware                                0.000000
# comp.windows.x                                       0.000000
# misc.forsale                                         0.000000
# rec.autos                                            0.000000
# rec.motorcycles                                      0.027993
# rec.sport.baseball                                   0.000000
# rec.sport.hockey                                     0.040472
# sci.crypt                                            0.432178
# sci.electronics                                      0.000000
# sci.med                                              0.000929
# sci.space                                            0.000000
# soc.religion.christian                               0.000000
# talk.politics.guns                                   0.035579
# talk.politics.mideast                                0.000000
# talk.politics.misc                                   0.000000
# talk.religion.misc                                   0.000000
#
#                           file, files, ftp, program, directory
# label
# alt.atheism                                           0.001382
# comp.graphics                                         0.000000
# comp.os.ms-windows.misc                               0.000000
# comp.sys.ibm.pc.hardware                              0.000000
# comp.sys.mac.hardware                                 0.000000
# comp.windows.x                                        0.008352
# misc.forsale                                          0.021623
# rec.autos                                             0.000000
# rec.motorcycles                                       0.000037
# rec.sport.baseball                                    0.216117
# rec.sport.hockey                                      0.000000
# sci.crypt                                             0.000000
# sci.electronics                                       0.000000
# sci.med                                               0.028964
# sci.space                                             0.000000
# soc.religion.christian                                0.000000
# talk.politics.guns                                    0.005927
# talk.politics.mideast                                 0.001913
# talk.politics.misc                                    0.000000
# talk.religion.misc                                    0.000000
#
# [20 rows x 30 columns]

# %% [markdown]
# -----
# ### Topic-based Classification
#
# If documents are composed of topics, we can leverage defined topics to
# classify new documents based on the topics that are assigned to each new
# document. In the following code cells, we first train a Naive Bayes
# classifier on the topics in the training data sample of the twenty
# newsgroup data set. We compute the topics, by using the previously
# created NMF model, for the test data and compute classifications from
# these topic models. Finally, the resulting classification report and
# confusion matrix are shown to demonstrate the quality of this
# classification method.
#
# -----

# %%
# Build classifier from topics.
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB().fit(td, train['target'])

# Apply classifier to blind test data
ts_preds = clf.predict(nmf.transform(test_data))

from sklearn import metrics

print(metrics.classification_report(test['target'], ts_preds,
    target_names = test['target_names']))
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.00      0.00      0.00       319
#            comp.graphics       0.44      0.33      0.37       389
#  comp.os.ms-windows.misc       0.56      0.53      0.54       394
# comp.sys.ibm.pc.hardware       0.40      0.40      0.40       392
#    comp.sys.mac.hardware       0.53      0.21      0.30       385
#           comp.windows.x       0.53      0.59      0.56       395
#             misc.forsale       0.61      0.60      0.60       390
#                rec.autos       0.72      0.45      0.55       396
#          rec.motorcycles       0.19      0.60      0.29       398
#       rec.sport.baseball       0.39      0.25      0.30       397
#         rec.sport.hockey       0.36      0.78      0.50       399
#                sci.crypt       0.51      0.65      0.57       396
#          sci.electronics       0.22      0.29      0.25       393
#                  sci.med       0.54      0.18      0.27       396
#                sci.space       0.62      0.61      0.61       394
#   soc.religion.christian       0.33      0.84      0.47       398
#       talk.politics.guns       0.43      0.06      0.10       364
#    talk.politics.mideast       0.94      0.61      0.74       376
#       talk.politics.misc       0.00      0.00      0.00       310
#       talk.religion.misc       0.00      0.00      0.00       251
#
#              avg / total       0.43      0.42      0.39      7532

# %%
# Create Confusion Plot
fig, ax = plt.subplots(figsize=(12, 10))

from helper_code import mlplots as mp
mp.confusion(test['target'], ts_preds, range(20), 20, 'Naive Bayes Model')

# %% [markdown]
# -----
# ### Student Activity
#
# In the preceding cells, we introduced basic topic modeling by using the
# scikit learn library and employed NMF in a text classification pipeline.
# Now that you have run the Notebook, why do you think the results from
# the topic model-based classification are so poor, especially when
# compared to the same algorithm without topic modeling (feel free to
# discuss this in the class forum)?
#
# Try making the following changes:
#
# 1. Increase the number of topics from six to sixty. Do the results change?
# 2. Change the classification algorithm to a random forest. Do the results
# change?
# 3. Try changing the TFIDF parameters to use more features and n-grams. Do
# the results change?
#
# -----
#
# ## Latent Dirichlet allocation
#
# Perhaps the most popular topic modeling algorithm is [Latent Dirichlet
# allocation][wlda] or LDA. LDA assumes that documents in a Corpus result
# from a mixture of a small number of topics,  and that the words in the
# document can be attributed to one of the topics that make up that
# document. The scikit learn library has an [LDA implementation][sklda],
# which can be easily applied to a data set, as demonstrated below. After
# constructing an LDA model, we extract the topics (in this case we are
# identifying topics for the newsgroup data set) and display the top terms
# in each topic.
#
# -----
# [wlda]: https://en.wikipedia.org/wiki/Latent_Dirichlet_allocation
# [sklda]: http://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html

# %%
from sklearn.decomposition import LatentDirichletAllocation

lda = LatentDirichletAllocation(n_topics=num_topics, max_iter=5,
                                learning_method='online', learning_offset=5.,
                                random_state=23).fit(train_data)

# %%
lda_topics = tp.get_topics(cv, lda)
# Out:
# Topic  0: ra mm jason 00 220 lane sale brand condition cylinder
# Topic  1: pitt gordon surrender banks cadre skepticism intellect geb shameful chastity
# Topic  2: greek turkish greece greeks cyprus turks kent cheers motorcycle island
# Topic  3: com captain 205 networking disc uunet traded sabres archie dave
# Topic  4: bmp s3 expensive direction logic incorrect commercial student shareware save
# Topic  5: w7 k8 2pl uw tl 3dy khf lhz 0t t7
# Topic  6: eh foods gov address did say think know like arizona
# Topic  7: holes rk rgb sounds rayshade tool handy faq like thanks
# Topic  8: windows thanks drive card use file does know dos pc
# Topic  9: tyre os2 chronic trace im dont vitamin called lee wires
# Topic 10: tires alomar gt quebec aluminum valve wheels da brake cylinder
# Topic 11: bus eisa isa dma dx vl xfree86 transfer cpu bm
# Topic 12: bj dn plug printer laser se printing pcs postscript happy
# Topic 13: ax israelis palestine gaza apartment reno steam venus ozone plants
# Topic 14: don just people like think know good time does right
# Topic 15: pts gp sex dec catalog gay stats frame 950 men
# Topic 16: pope bishop rc marriage largest seats screwed witnesses true just
# Topic 17: simms vesa vlb vram simm radar megs detector 4mb vertical
# Topic 18: god jesus christ heaven christians sin faith hell scripture lord
# Topic 19: key clipper encryption chip keys nsa escrow algorithm crypto des
# Topic 20: polygon scan jupiter routine glass postscript adobe pp fonts roman
# Topic 21: cancer alan pt mets stopping posts fell accurate regularly question
# Topic 22: steve ye shall contacts posters rec motorcycles sharks face posting
# Topic 23: accelerator lebanese paradise 800 rockefeller outlet robert scsi vga pin
# Topic 24: msg food eat chinese mydisplay abs vitamin sleeve meat taste
# Topic 25: produced cleveland stands ignorant damage fun did body ve great
# Topic 26: buyer modems baud hst biz modem 2400 usr external meg
# Topic 27: dh ho lb pl p2 printf dm ut p1 fg
# Topic 28: hawks vax jason stadium stephanopoulos blues jackson label wave platform
# Topic 29: f1 hudson kk modes mask position assistance neat adaptec george

# %% [markdown]
# -----
#
# ### Visualizing Topics
#
# We can visualize he important terms in a topic by constructing a
# [wordle][ww], which is a word cloud where the size of the word indicates
# its relative importance. To do this, we will use the Python [word cloud][pwn]
# library as demonstrated in the following code cell, where we display a
# word cloud for the first topic and a word cloud for all topics.
#
# -----
# [ww]: http://www.wordle.net
# [pwn]: http://amueller.github.io/word_cloud/

# %%
from helper_code import wcviz as wc

wc.make_wc(lda_topics[0].replace(',', ''), 'Words from Topic 0')

text = ', '.join(lda_topics)
wc.make_wc(text.replace(',', ''), 'Words from all Topics')

# %% [markdown]
# -----
#
# ### Student Activity
#
# In the preceding cells, we introduced Latent Dirichlet allocation. Now
# that you have run the Notebook, try to use LDA in the previous text
# classification problem. Are the results better or worse? Can you explain
# why?
#
# -----
#
# ## Gensim
#
# While NLTK is a useful library to learn the basic concepts in text
# analysis and natural language processing, there are other libraries that
# provide powerful NLP functionality. One of the most important libraries
# in this category is the [_gensim_ library][gl], which is an open source,
# Python library to create vector-space models for text data that can be
# used to create topic models. In the following section, we review how to
# use the gensim library to perform basic text analysis, before learning
# how to use gensim  to create topic models.
#
# An important task in gensim is to the creation of the vector space model
# for a text document. The indices into the vector space are mapped to the
# actual terms (or words) by a dictionary; thus we will need the actual
# vector space model and this dictionary to use gensim for topic
# modeling. These concepts are demonstrated in the following few code
# cells, where we analyze the course description.
#
# -----
# [gl]: http://radimrehurek.com/gensim/

# %%
# Next section follows gensim tutorial

# As a text example, we use the course description for INFO490  SP16.
info_course = ['Advanced Data Science: This class is an asynchronous, online course.', 
               'This course will introduce advanced data science concepts by building on the foundational concepts presented in INFO 490: Foundations of Data Science.', 
               'Students will first learn how to perform more statistical data exploration and constructing and evaluating statistical models.', 
               'Next, students will learn machine learning techniques including supervised and unsupervised learning, dimensional reduction, and cluster finding.', 
               'An emphasis will be placed on the practical application of these techniques to high-dimensional numerical data, time series data, image data, and text data.', 
               'Finally, students will learn to use relational databases and cloud computing software components such as Hadoop, Spark, and NoSQL data stores.', 
               'Students must have access to a fairly modern computer, ideally that supports hardware virtualization, on which they can install software.', 
               'This class is open to sophomores, juniors, seniors and graduate students in any discipline who have either taken a previous INFO 490 data science course or have received instructor permission.']

# Simple stop words
stop_words = set('for a of the and to in on an'.split())

# Parse text into words, make lowercase and remove stop words
txts = [[word for word in sentance.lower().split() if word not in stop_words]
        for sentance in info_course]

# Keep only those words appearing more than once
# Easy with a Counter, but need a flat list
from collections import Counter
frequency = Counter([word for txt in txts for word in txt])

# Now grab tokens that appear more than once
tokens = [[token for token in txt if frequency[token] > 1]
          for txt in txts]

# Display the tokens
import pprint
pp = pprint.PrettyPrinter(indent=2, depth=2, width=80, compact=True)

pp.pprint(tokens)
# Out:
# [ ['advanced', 'data', 'this', 'class', 'is'],
#   [ 'this', 'course', 'will', 'advanced', 'data', 'science', 'concepts',
#     'concepts', 'info', 'data'],
#   ['students', 'will', 'learn', 'statistical', 'data', 'statistical'],
#   ['students', 'will', 'learn', 'techniques'],
#   ['will', 'techniques', 'data,', 'data,', 'data,'],
#   ['students', 'will', 'learn', 'data'], ['students', 'have'],
#   [ 'this', 'class', 'is', 'students', 'have', 'info', 'data', 'science',
#     'course', 'have']]

# %%
# Compute dictionary mapptin for given text corpus

from gensim import corpora
dict_gensim = corpora.Dictionary(tokens)
print(dict_gensim)
# Out:
# Dictionary(16 unique tokens: ['techniques', 'will', 'data', 'science', 'have']...)

# %%
# Display mapping between index and word in Bag of Word model.

print(dict_gensim.token2id)
# Out:
# {'techniques': 13, 'will': 8, 'data': 4, 'science': 5, 'have': 15, 'data,': 14, 'class': 1, 'advanced': 2, 'course': 7, 'concepts': 6, 'this': 0, 'learn': 10, 'statistical': 11, 'is': 3, 'students': 12, 'info': 9}

# %%
# Display sample text string as a bag of words.

new_txt = 'data science is cool, you should take this course to learn data concepts'
new_vec = dict_gensim.doc2bow(new_txt.lower().split())
pp.pprint(new_vec)
# Out:
# [(0, 1), (3, 1), (4, 2), (5, 1), (6, 1), (7, 1), (10, 1)]

# %%
# Display corpus as bag of words.

crps = [dict_gensim.doc2bow(txt) for txt in txts]
print(crps)
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1)], [(0, 1), (2, 1), (4, 2), (5, 1), (6, 2), (7, 1), (8, 1), (9, 1)], [(4, 1), (8, 1), (10, 1), (11, 2), (12, 1)], [(8, 1), (10, 1), (12, 1), (13, 1)], [(8, 1), (13, 1), (14, 3)], [(4, 1), (8, 1), (10, 1), (12, 1)], [(12, 1), (15, 1)], [(0, 1), (1, 1), (3, 1), (4, 1), (5, 1), (7, 1), (9, 1), (12, 1), (15, 2)]]

# %% [markdown]
# -----
#
# ### Topic Modeling with gensim
#
# We can use the gensim library to perform topic modeling. We first
# transform our info text document to a TFIDF model. The gensim library
# requires a dictionary to map indices into the TFIDF model to the words,
# which we can do with our `dict_gensim` object. In the next few code
# cells, we first create our TFIDF document matrix, display the a sample
# text string, the bag of words model for this text strings, and the TFIDF
# model of this document. Next, we construct an Latent Dirchlet allocation
# model of this document using our dictionary mapping object. Finally, we
# display the topics, before quantifying the top topic for each sentence
# in our original corpus.
#
# -----

# %%
crps
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1)],
#  [(0, 1), (2, 1), (4, 2), (5, 1), (6, 2), (7, 1), (8, 1), (9, 1)],
#  [(4, 1), (8, 1), (10, 1), (11, 2), (12, 1)],
#  [(8, 1), (10, 1), (12, 1), (13, 1)],
#  [(8, 1), (13, 1), (14, 3)],
#  [(4, 1), (8, 1), (10, 1), (12, 1)],
#  [(12, 1), (15, 1)],
#  [(0, 1), (1, 1), (3, 1), (4, 1), (5, 1), (7, 1), (9, 1), (12, 1), (15, 2)]]

# %%
from gensim import models

tfidf = models.TfidfModel(crps)

# %%
# Print sentance, bago of words model, and TFIDF representation.

print(new_txt)
print(new_vec)

pp.pprint(tfidf[new_vec])
# Out:
# data science is cool, you should take this course to learn data concepts
# [(0, 2), (1, 1), (2, 1), (5, 1), (6, 1), (9, 1), (11, 1)]
# [ (0, 0.2617482842884797), (1, 0.2731153103729994), (2, 0.3860184772660643),
#   (5, 0.3860184772660643), (6, 0.5790277158990964), (9, 0.3860184772660643),
#   (11, 0.2731153103729994)]

# %%
# Compute LDA model for corpus

crps_tfidf = tfidf[crps]
lda_gs = models.LdaModel(corpus=crps_tfidf, id2word=dict_gensim, num_topics=3, passes=15)

# %%
# Display topics as functions over their top terms

lda_gs.print_topics(3)
# Out:
# ['0.114*concepts + 0.113*advanced + 0.094*this + 0.090*is + 0.090*class + 0.072*data + 0.061*info + 0.061*course + 0.061*science + 0.042*will',
#  '0.187*have + 0.124*statistical + 0.081*students + 0.062*science + 0.062*info + 0.062*course + 0.060*class + 0.060*is + 0.051*this + 0.048*data',
#  '0.171*learn + 0.123*techniques + 0.122*data, + 0.105*will + 0.093*students + 0.069*data + 0.033*statistical + 0.031*course + 0.031*info + 0.031*science']

# %%
# Determine primary topic for each sentance in original text
import operator

for idx, txt in enumerate(lda_gs[crps_tfidf]):
    srt_txt = sorted(txt, key=operator.itemgetter(1))
    print('Sentance {0:1d} has primary topic {1:1d} with probability = {2:4.3f}'\
          .format(idx, srt_txt[-1][0], srt_txt[-1][1]))
# Out:
# Sentance 0 has primary topic 0 with probability = 0.778
# Sentance 1 has primary topic 0 with probability = 0.783
# Sentance 2 has primary topic 1 with probability = 0.584
# Sentance 3 has primary topic 2 with probability = 0.759
# Sentance 4 has primary topic 2 with probability = 0.703
# Sentance 5 has primary topic 2 with probability = 0.758
# Sentance 6 has primary topic 1 with probability = 0.696
# Sentance 7 has primary topic 1 with probability = 0.758

# %%
ttps = lda_gs.top_topics(corpus=crps_tfidf, num_words=5)
idx = 0

for lst, val in ttps:
    print('Topic {0}'.format(idx))
    print(35*('-'))
    idx += 1
    for i, z in lst:
        print('    {0:20s}: {1:5.4f}'.format(z, i))
    print(35*('-'))
# Out:
# Topic 0
# -----------------------------------
#     concepts            : 0.1138
#     advanced            : 0.1130
#     this                : 0.0935
#     is                  : 0.0897
#     class               : 0.0897
# -----------------------------------
# Topic 1
# -----------------------------------
#     have                : 0.1866
#     statistical         : 0.1237
#     students            : 0.0809
#     science             : 0.0624
#     info                : 0.0624
# -----------------------------------
# Topic 2
# -----------------------------------
#     learn               : 0.1713
#     techniques          : 0.1225
#     data,               : 0.1222
#     will                : 0.1053
#     students            : 0.0934
# -----------------------------------

# %% [markdown]
# -----
#
# ### Topic Modeling with gensim
#
# We can use the gensim library to perform topic modeling of the twenty
# newsgroup data. We first need to transform a sparse matrix (as provided
# by the scikit learn library) into a gensim corpus. We also need to
# construct a vocabulary dictionary, which we can do by transforming the
# scikit learn `CountVectorizer` vocabulary into a dictionary that maps
# between `id` and the `word`. We demonstrate this transformation in the
# following code cell for the newsgroup training data.
#
# -----

# %%
train_data
# Out:
# <11314x5000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 498948 stored elements in Compressed Sparse Row format>

# %%
from gensim import matutils as mat
from gensim import models as md
from gensim.corpora.dictionary import Dictionary

# transform sparse matrix into gensim corpus
td_gensim = mat.Sparse2Corpus(train_data, documents_columns=False)

# Build temporary dictionary from scikit learn vectorizer
# for use with gensim
tmp_dct = dict((idv, word) for word, idv in cv.vocabulary_.items())
dct = Dictionary.from_corpus(td_gensim, id2word=tmp_dct)

# %% [markdown]
# -----
#
# ### Latent Semantic Analysis
#
# We can use the gensim library to perform [Latent Semantic
# Analysis][wlsa] or LSA; in gensim, however, this technique is called
# [Latent Semantic Indexing][glsi] (or LSI). LSA assumes that words with
# similar meanings will occur in close proximity. By leveraging this
# assumption, we can build and process a term document matrix. After
# processing, a cosine similarity can be used to identify words that are
# similar. This technique is applied in the following code cell, where we
# build an LSA model with six topics from the newsgroup text. The topics
# are subsequently displayed as functions of the most important terms in
# each topic.
#
# -----
# [wlsa]: https://en.wikipedia.org/wiki/Latent_semantic_analysis
# [glsi]: http://radimrehurek.com/gensim/models/lsimodel.html

# %%
# LSI

lsi = md.lsimodel.LsiModel(corpus=td_gensim, id2word=dct, num_topics=6)
lsi.print_topics()
# Out:
# ['0.167*"don" + 0.164*"just" + 0.162*"like" + 0.161*"know" + 0.153*"people" + 0.138*"think" + 0.128*"does" + 0.115*"good" + 0.114*"use" + 0.110*"time"',
#  '-0.256*"god" + 0.241*"windows" + 0.229*"thanks" + -0.190*"people" + 0.157*"card" + 0.148*"drive" + 0.124*"dos" + -0.114*"jesus" + 0.114*"mail" + 0.113*"file"',
#  '0.492*"god" + 0.175*"jesus" + 0.155*"windows" + 0.149*"does" + 0.131*"thanks" + -0.125*"year" + -0.122*"game" + 0.117*"bible" + -0.116*"pitt" + -0.116*"geb"',
#  '0.265*"edu" + 0.239*"geb" + 0.236*"dsl" + 0.236*"chastity" + 0.236*"n3jxp" + 0.236*"cadre" + 0.235*"shameful" + 0.235*"pitt" + 0.235*"skepticism" + 0.234*"intellect"',
#  '-0.314*"key" + 0.249*"drive" + 0.215*"god" + -0.175*"government" + -0.169*"encryption" + -0.164*"chip" + -0.149*"clipper" + 0.143*"game" + -0.137*"use" + -0.129*"keys"']

# %% [markdown]
# -----
#
# ### Latent Dirichlet allocation
#
# The gensim library also provides an implementation of the [Latent
# Dirichlet allocation][glda] or LDA. We demonstrate the gensim LDA
# technique in the following code cell, where we once again create an LDA
# model with six topics for the newsgroup text. We subsequently display
# the topics as functions of the top words within each topic. Finally, we
# display the top five words in each topic, along with their topic
# coherence, which is a measure of the words importance to the specific
# topic.
#
# -----
#
# [glda]: http://radimrehurek.com/gensim/models/ldamodel.html

# %%
# LDA

lda_gs = md.LdaModel(corpus=td_gensim, id2word=dct, num_topics=6, passes=2)
lda_gs.show_topics()

# %%
ttps = lda_gs.top_topics(corpus=td_gensim, num_words=5)

# %%
idx = 0

for lst, val in ttps:
    print('Topic {0}'.format(idx))
    print(35*('-'))
    idx += 1
    for i, z in lst:
        print('    {0:20s}: {1:5.4f}'.format(z, i))
    print(35*('-'))
# Out:
# Topic 0
# -----------------------------------
#     pitt                : 0.0123
#     gordon              : 0.0110
#     banks               : 0.0105
#     surrender           : 0.0105
#     cadre               : 0.0103
# -----------------------------------
# Topic 1
# -----------------------------------
#     car                 : 0.0047
#     like                : 0.0042
#     just                : 0.0041
#     good                : 0.0039
#     don                 : 0.0034
# -----------------------------------
# Topic 2
# -----------------------------------
#     thanks              : 0.0055
#     windows             : 0.0049
#     use                 : 0.0046
#     know                : 0.0044
#     does                : 0.0042
# -----------------------------------
# Topic 3
# -----------------------------------
#     people              : 0.0066
#     god                 : 0.0054
#     don                 : 0.0042
#     think               : 0.0038
#     government          : 0.0035
# -----------------------------------
# Topic 4
# -----------------------------------
#     team                : 0.0055
#     game                : 0.0052
#     jesus               : 0.0038
#     year                : 0.0038
#     season              : 0.0038
# -----------------------------------
# Topic 5
# -----------------------------------
#     just                : 0.0063
#     baseball            : 0.0052
#     braves              : 0.0043
#     cubs                : 0.0041
#     ax                  : 0.0038
# -----------------------------------

# %% [markdown]
# -----
#
# ### Student Activity
#
# In the preceding cells, we used the gensim library to perform topic
# modeling on the twenty newsgroup data set. Now that you have n the
# Notebook, try making the following changes.
#
# 1. Increase the number of topics, how do the results change?
# 2. Can you map the topics to the original newsgroups?
#
# -----
